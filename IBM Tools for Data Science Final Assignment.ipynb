# %% [markdown]
#  # <center>$\color{red}{\text{My Jupyter Notebook on IBM Watson Studio}}$ </center>

# %% [markdown]
# <strong> Michal Kotecki </strong> </p>
# Drilling Engineer

# %% [markdown]
# *I am interested in Data Science and Data Analyst due to possibilites of taking right development and business decisions*

# %% [markdown]
# ### The following code displays the first 10 square numbers

# %%
for n in range(1,11):
    print(n**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# This cell is dysplaying several rules
# ***
# Horizontal rule
#
# 1. Numbered list
# * Bullet list
#     * Table
#
#      | Category                 1 | Varialble 1 | Variable 2 |
#     | :---|:---:| ---:|
# | This is row  | for words | only |
# |   This is row for numbers  |   25.09  |   $99.49 |
# | This row shows special characters |    &#9638;  |  &#x25BA;|
#
# ~~They can be found in the link below:~~
#
# Sorry &#9996;
#
# There can be found in the link below:
#
# [Geometric shapes](https://www.w3schools.com/charsets/ref_utf_geometric.asp "Geometric Shapes")
#
# 2. ```python
# s = "Python syntax highlighting"
# print s
# ```
#
# 3. Image ![Albino-burmese-python-on-transparent-background-PNG.png](attachment:Albino-burmese-python-on-transparent-background-PNG.png "Python")
